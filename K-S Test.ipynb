# %%
import numpy as np
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt

# generate a gaussian r.v X
x = stats.norm.rvs(size=1000)
sns.set_style('whitegrid')
sns.kdeplot(np.array(x),bw_method=0.5)
plt.show()

# %%
stats.kstest(x,'norm')
# Out:
# KstestResult(statistic=0.03635117131499899, pvalue=0.13884036344942374)

# %%
# y ~ Continous Uniform Distribution(0,1)
y = np.random.uniform(0,1,10000)
sns.kdeplot(np.array(y),bw_method=0.1)
plt.show()

# %%
stats.kstest(y,'norm')
# Out:
# KstestResult(statistic=0.5000742155639194, pvalue=0.0)
